# %% [markdown]
# ## 滑動視窗(Sliding Window)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 那回到滑動視窗演算法，也是差不多的概念，透過使用一個可變的視窗大小或固定視窗大小來解題，
# ### 通常多用在字串或陣列的問題，當然這有些題目可以透過暴力解法解決，
# ### 但使用滑動視窗演算法可將時間複雜度

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 參考資料

# %% [markdown]
# https://www.zhihu.com/question/314669016

# %% [markdown]
# ### sliding window & two pointer

# %% [markdown]
# https://medium.com/%E6%8A%80%E8%A1%93%E7%AD%86%E8%A8%98/%E6%BC%94%E7%AE%97%E6%B3%95%E7%AD%86%E8%A8%98%E7%B3%BB%E5%88%97-two-pointer-%E8%88%87sliding-window-8742f45f3f55

# %% [markdown]
# ## 相關題目

# %% [markdown]
# ### 3. Longest Substring Without Repeating Characters
# ### 26. Remove Duplicates from Sorted Array
# ### 80. Remove Duplicates from Sorted Array II
# ### 167. Two Sum II — Input array is sorted v
# ### 209. Minimum Size Subarray Sum v
# ### 977. Squares of a Sorted Array v

# %% [markdown]
# ## hash table
